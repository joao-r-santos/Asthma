# %%
import json

# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('http://www.cehtp.org/page/asthma/results?EVENT=ASED&TYPE=R10K&RACE=TOTL&AGE=TOTL&SEX=TOTL&MODEL=CONV&YEAR=2006&GEOG=CTY')

soup = BeautifulSoup(response.text,'lxml')

# %%
print soup.prettify
# Out:
# <bound method BeautifulSoup.prettify of <!DOCTYPE html>\n<html><head><style type="text/css">.gm-style .gm-style-mtc label,.gm-style .gm-style-mtc div{font-weight:400}</style><link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700" rel="stylesheet" type="text/css"><style type="text/css">.gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px}</style><style type="text/css">@media print {  .gm-style .gmnoprint, .gmnoprint {    display:none  }}@media screen {  .gm-style .gmnoscreen, .gmnoscreen {    display:none  }}</style><style type="text/css">.gm-style-pbc{transition:opacity ease-in-out;background-color:rgba(0,0,0,0.45);text-align:center}.gm-style-pbt{font-size:22px;color:white;font-family:Roboto,Arial,sans-serif;position:relative;margin:0;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%)}</style><style type="text/css">.gm-style { font: 400 11px Roboto, Arial, sans-serif;text-
# ...

# %%
tables= soup.find_all('table')

# %%
for table in tables:
    print table.find_all('td')
# Out:
# [<td id="page-breadcrumb" style="text-align: left; padding-left: 5px; width: 70%; height: 30px;"><a href="/">Home</a> &gt; <a href="asthma">Asthma</a> &gt; <a href="/page/asthma/query">Query</a> &gt; <strong>Data Query Results</strong></td>, <td style="text-align: right; padding-right: 5px;">\n</td>]
# []
# [<td colspan="5">No matching records found</td>]
# []

# %%
import numpy as np

# %%
{'GEOG': ['CTY'],
 'EVENT': ['ASED','ASHO'],
 'YEAR': list(map(np.str,np.arange(2000,2015,1))),
 'RACE': ['TOTL','AFAM','ASPI','HISP','WHIT','OTHR'],
 'AGE': ['TOTL','0004','0517','1834','3564','65OV','0017','18OV'],
 'SEX': ['TOTL','FEML','MALE'],
 'MODEL': ['CONV','BBYM'],
 'TYPE': ['R10K','CR10L']}
# Out:
# {'AGE': ['TOTL', '0004', '0517', '1834', '3564', '65OV', '0017', '18OV'],
#  'EVENT': ['ASED', 'ASHO'],
#  'GEOG': ['CTY'],
#  'MODEL': ['CONV', 'BBYM'],
#  'RACE': ['TOTL', 'AFAM', 'ASPI', 'HISP', 'WHIT', 'OTHR'],
#  'SEX': ['TOTL', 'FEML', 'MALE'],
#  'TYPE': ['R10K', 'CR10L'],
#  'YEAR': ['2000',
#   '2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012',
#   '2013',
#   '2014']}

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(rendered_html, 'html.parser')

# %%
tables = soup.find_all('table')

# %%
for table in tables:
    print table
# Out:
# <table style="width: 100%;">
# <tbody>
# <tr>
# <td id="page-breadcrumb" style="text-align: left; padding-left: 5px; width: 70%; height: 30px;"><a href="/">Home</a> &gt; <a href="asthma">Asthma</a> &gt; <a href="/page/asthma/query">Query</a> &gt; <strong>Data Query Results</strong></td>
# <td style="text-align: right; padding-right: 5px;">
# </td>
# </tr>
# </tbody>
# </table>
# <table></table>
# <table class="table table-hover table-condensed table-striped" data-classes="table table-hover table-condensed" data-sorter="rateSorter" data-striped="true" data-toggle="table" data-url="/page/dataQuery/table/asthma">
# <thead>
# ...

# %%
from selenium import webdriver

# %%
browser = webdriver.Chrome() #selenium for Chrome

browser.get(url)
time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-3638558ca112> in <module>()
#       2
#       3 browser.get(url)
# ----> 4 time(5)
#
# TypeError: 'module' object is not callable

# %%
browser.page_source
# Out:
# u'<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml"><head><style type="text/css">.gm-style .gm-style-mtc label,.gm-style .gm-style-mtc div{font-weight:400}</style><link type="text/css" rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700" /><style type="text/css">.gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px}</style><style type="text/css">@media print {  .gm-style .gmnoprint, .gmnoprint {    display:none  }}@media screen {  .gm-style .gmnoscreen, .gmnoscreen {    display:none  }}</style><style type="text/css">.gm-style { font: 400 11px Roboto, Arial, sans-serif;text-decoration: none; }.gm-style img { max-width: none; }</style>\n    <title>California Environmental Health Tracking</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0" />\n\n    <link href="/styles/ca_master.css" rel="stylesheet" media="screen" />\n    <link href="/styles/ca_department.css" rel="stylesh
# ...

# %%
html_source = browser.page_source
soup = BeautifulSoup(html_source) #fetch HTML source code after rendering
browser.quit()

# %%
import time

# %%
driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('http://www.google.com/xhtml');

# %%
time.sleep(5) # Let the user actually see something!
search_box = driver.find_element_by_name('q')

# %%
search_box.send_keys('ChromeDriver')
search_box.submit()
time.sleep(5) # Let the user actually see something!
driver.quit()

# %%
webdriver.Chrome?
