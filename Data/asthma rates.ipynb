# %% [markdown]
# # Asthma ER visits per county and per year

# %% [markdown]
# From the original data file in csv format, extract the features we want, as well as the rows

# %% [markdown]
# In this first approach, get the ER visits numbers and rates for all children (under 18) for the year 2014

# %%
import numpy as np
import pandas as pd

# %%
filename= 'raw/Asthma_ED_Visit_Rates__LGHC_Indicator_07_.csv'
# np.loadtxt(filename, delimiter=',', skiprows=)

# %%
data = pd.read_csv(filename)

# %%
data
# Out:
#         LGHC Indicator Name        Geography  Year Age Group  \
# 0     Asthma ED Visit Rates          Alameda  2015  Under 18
# 1     Asthma ED Visit Rates           Amador  2015  Under 18
# 2     Asthma ED Visit Rates            Butte  2015  Under 18
# 3     Asthma ED Visit Rates        Calaveras  2015  Under 18
# 4     Asthma ED Visit Rates       California  2015  Under 18
# 5     Asthma ED Visit Rates           Colusa  2015  Under 18
# 6     Asthma ED Visit Rates     Contra Costa  2015  Under 18
# 7     Asthma ED Visit Rates        Del Norte  2015  Under 18
# 8     Asthma ED Visit Rates        El Dorado  2015  Under 18
# 9     Asthma ED Visit Rates           Fresno  2015  Under 18
# 10    Asthma ED Visit Rates            Glenn  2015  Under 18
# 11    Asthma ED Visit Rates         Humboldt  2015  Under 18
# 12    Asthma ED Visit Rates         Imperial  2015  Under 18
# 13    Asthma ED Visit Rates             Inyo  2015  Under 18
# ...
